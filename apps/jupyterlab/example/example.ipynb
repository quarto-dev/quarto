# %% [markdown]
# ---
# title: Hello World
# author:
#   - name: Charles Teague
#     orcid: 0000-0001-8715-9476
#     affiliations:
#       - Macalester College
#       - Posit, PBC
#   - name: Norah Jones
#     affiliation: Blue Note Records
# date: 2023-10-04
# doi: 10.1542/hpeds.2016-0177
# abstract: |
#   Pellentesque vulputate orci aliquam, mollis ipsum quis, iaculis neque. Suspendisse potenti. Mauris vestibulum eros at nulla sodales laoreet. Morbi ligula sem, sollicitudin eu gravida sed, cursus ultricies ante. Aenean posuere interdum elit sit amet aliquet. Cras non convallis diam. In iaculis, dolor vitae sodales viverra, mi sem congue nisi, suscipit lobortis ante ipsum a lacus. Praesent placerat vitae lorem sit amet venenatis. Morbi gravida porta lectus eget blandit.
# format:
#   html:
#     theme: spacelab
#   pdf: default
# ---

# %% [markdown]
# ### The Basics
#
# Of course, the basics of a notebook (mixing of code cells and markdown cells) works exactly as expected.

# %%
#| label: fig-polar
#| fig-cap: "A line plot on a polar axis"

import numpy as np
import matplotlib.pyplot as plt

r = np.arange(0, 2, 0.01)
theta = 2 * np.pi * r
fig, ax = plt.subplots(
  subplot_kw = {'projection': 'polar'} 
)
ax.plot(theta, r)
ax.set_rticks([0.5, 1, 1.5, 2])
ax.grid(True)
plt.show()

# %% [markdown]
# ### Figures
#
# ![A very cool image of a person working very hard.](working.jpeg){#fig-elephant}
#
# This is illustrated well by @fig-elephant.

# %% [markdown]
# ## Figure Divs
#
# You can also use a `div` to make a figure, a 'figure div' like so:
#
# ::: {#fig-elephant}
#
# ![](working.jpeg)
#
# A very cool image of a person working very hard.
#
# :::

# %%
#| label: tbl-pandas-example
#| tbl-cap: This is a computationally generated example table.
import pandas as pd
import numpy as np
technologies   = ({
    'Courses':["Spark","PySpark","Hadoop","Python","Pandas",None,"Spark","Python"],
    'Fee' :[22000,25000,23000,24000,np.nan,25000,25000,22000],
    'Duration':['30day','50days','55days','40days','60days','35day','','50days'],
    'Discount':[1000,2300,1000,1200,2500,1300,1400,1600]
          })
row_labels=['r0','r1','r2','r3','r4','r5','r6','r7']
df = pd.DataFrame(technologies, index=row_labels)
display(df)
# Out:
#     Courses      Fee Duration  Discount
# r0    Spark  22000.0    30day      1000
# r1  PySpark  25000.0   50days      2300
# r2   Hadoop  23000.0   55days      1000
# r3   Python  24000.0   40days      1200
# r4   Pandas      NaN   60days      2500
# r5     None  25000.0    35day      1300
# r6    Spark  25000.0               1400
# r7   Python  22000.0   50days      1600

# %% [markdown]
# ### Fenced Div Support
#
# The Quarto extension for JupyterLab will properly render 'fenced divs', which look like:
#
# :::{#foobar .class1 myAttr="cool"}
#
# Hi! This is the body of a div!
#
# :::
#
# In Quarto, fenced divs are useful for a variety of things, such as customizing layout, creating tabsets, or even marking conditional regions.

# %% [markdown]
# ### Tables
#
# The plugin can also preview tables (grid or markdown) with captions, ids, and other decorations.
#
# #### Grid
#
# +---------------+---------------+--------------------+
# | Fruit         | Price         | Advantages         |
# +===============+===============+====================+
# | Bananas       | $1.34         | - built-in wrapper |
# |               |               | - bright color     |
# +---------------+---------------+--------------------+
# | Oranges       | $2.10         | - cures scurvy     |
# |               |               | - tasty            |
# +---------------+---------------+--------------------+
#
# : This is a sample grid table {#tbl-grid}
#
# #### Markdown Tables
#
# | Col1 | Col2 | Col3 |
# |------|------|------|
# | A    | B    | C    |
# | E    | F    | G    |
# | A    | G    | G    |
#
# : My Caption {#tbl-letters}
#
# See @tbl-letters.

# %% [markdown]
# ### Citations
#
# To cite a bibliographic item with an identifier foo, use the syntax @foo. Normal citations should be included in square brackets, with semicolons separating distinct items:
#
# Blah blah [@doe99; @smith2000; @smith2004].
#
# Blah blah [see @doe99, pp. 33-35 and *passim*; @smith04, chap. 1].
#
# Smith says blah [-@smith04].
#
# @smith04 says blah.
#
# @smith04 [p. 33] says blah.
#
# Escaped, like @{Foo_bar.baz.}.
#
# All of the above are examples of valid citations that should render properly. If they are not higlighted, then something in the extension isn't working as intended.

# %% [markdown]
# ### Callouts
#
# Quarto supports a variety of different types of callouts, which enabled highlighting important content or providing additional content outside the flow of the existing paragraph.
#
# Some examples include:
#
# ::: callout-note
# Note that there are five types of callouts, including: `note`, `tip`, `warning`, `caution`, and `important`.
#
# :::
#
# ::: callout-warning
# Callouts provide a simple way to attract attention, for example, to this warning.
#
# :::
#
# ::: callout-important
# ## This is Important
#
# Danger, callouts will really improve your writing.
#
# :::
#
# ::: callout-tip
# ## Tip With Title
#
# This is an example of a callout with a title.
#
# :::
#
# ::: {.callout-caution collapse="true"}
# ## Expand To Learn About Collapse
#
# This is an example of a 'collapsed' caution callout that can be expanded by the user. You can use `collapse="true"` to collapse it by default or `collapse="false"` to make a collapsible callout that is expanded by default.
#
# :::

# %% [markdown]
# ### Code
#
# There are wide variety of options available to customize the display of source code within HTML documents. Below is simple code cell. Note the highlighting.
#
# ```python
# def fizz_buzz(num):
#   if num % 15 == 0:
#     print("FizzBuzz")
#   elif num % 5 == 0:
#     print("Buzz")
#   elif num % 3 == 0:
#     print("Fizz")
#   else:
#     print(num)
# ```
#
# ```javascript
# const foo = "bar";
# let bar = foo;
# for (let i = 0; i < 10; i++) {
#   console.log(`${i} bar`);
#   bar = `bar-${i}`;
# }
# ```

# %% [markdown]
# ### Diagrams
#
# Mermaid is a Javascript based diagramming and charting tool that uses Markdown-inspired text definitions and a renderer to create and modify complex diagrams.
#
# Above we demonstrated a flowchart created with Mermaid, here is a sequence diagram (also embedded using a {mermaid} executable cell):
#
# ```{mermaid}
# sequenceDiagram
#   participant Alice
#   participant Bob
#   Alice->>John: Hello John, how are you?
#   loop Healthcheck
#     John->>John: Fight against hypochondria
#   end
#   Note right of John: Rational thoughts <br/>prevail!
#   John-->>Alice: Great!
#   John->>Bob: How about you?
#   Bob-->>John: Jolly good!
# ```

# %% [markdown]
# ### Tabsets
#
# Create a tabset via a markdown div with the class name panel-tabset (e.g. ::: {.panel-tabset}). Each top-level heading within the div creates a new tab. For example, here is the markdown used to implement the first two tabs displayed above:
#
# :::{.panel-tabset}
#
# ## R
#
# ```r
# fizz_buzz <- function(fbnums = 1:50) {
#   output <- dplyr::case_when(
#     fbnums %% 15 == 0 ~ "FizzBuzz",
#     fbnums %% 3 == 0 ~ "Fizz",
#     fbnums %% 5 == 0 ~ "Buzz",
#     TRUE ~ as.character(fbnums)
#   )
#   print(output)
# }
# ```
#
# ## Python
#
# ```python
# def fizz_buzz(num):
#   if num % 15 == 0:
#     print("FizzBuzz")
#   elif num % 5 == 0:
#     print("Buzz")
#   elif num % 3 == 0:
#     print("Fizz")
#   else:
#     print(num)
# ```
#
# :::

# %% [markdown]
# ### Math
#
# Inline math expressions like $e=Mc^2$ or $A^2 + B^2 = C^2$ now properly render (using a remote URL to access MathJax).
#
# Block math expressions also render properly. For example, Black-Scholes @eq-black-scholes is a mathematical model that seeks to explain the behavior of financial derivatives, most commonly options:
#
# $$
# \frac{\partial \mathrm C}{ \partial \mathrm t } + \frac{1}{2}\sigma^{2} \mathrm S^{2}
# \frac{\partial^{2} \mathrm C}{\partial \mathrm C^2}
#   + \mathrm r \mathrm S \frac{\partial \mathrm C}{\partial \mathrm S}\ =
#   \mathrm r \mathrm C
# $$ {#eq-black-scholes}
#
# or
#
# $$
# \sum_{n=0}^{\infty}\frac{(-1)^n}{(2n+1)!}\left[\frac{\partial^{2n+1}}{\partial x^{2n+1}}\left(\frac{1}{\sqrt{1-x^2}}\right)\right]^2 = \frac{\pi}{2(2\pi)^{2n}}\frac{\Gamma^2\left(n+\frac{1}{2}\right)}{\Gamma(2n+1)}
# $$
#
# or
#
# $$
# \sum_{k=0}^{\infty} \frac{(-1)^k x^{2k+1}}{(2k+1)!} = \sin x
#
# \frac{\partial}{\partial t}\left(\rho\frac{\partial\mathbf{u}}{\partial t}\right) + \nabla\cdot\left(\rho\mathbf{u}\otimes\mathbf{u}\right) + \nabla p - \nabla\cdot\boldsymbol{\tau} + \rho\mathbf{g} = \rho\frac{\partial\mathbf{u}}{\partial t}
# $$ {#eq-made-up .foobar}

# %% [markdown]
# ### Listings
#
# #### Code
#
# ```{#lst-customers .sql lst-cap="Customers Query"}
# SELECT * FROM Customers
# ```
#
# Then we query the customers database @lst-customers.
#
# ::: {#thm-line}
#
# ## Thereoms
#
# The equation of any straight line, called a linear equation, can be written as:
#
# $$
# y = mx + b
# $$
# :::
#
# See @thm-line.

# %% [markdown]
# #### Figure Div
#
# You can make anything a figure by using a div with an id prefixed by `#fig-` to wrap the contents with a figure.
#
# :::{#fig-elephant}
# This is a test
#
# A very cool image of a person working very hard.
# :::

# %% [markdown]
# ### Spans
#
# [This is a span of text]{.foo} with a call applied to it. Should there be any special treatment? It should definitely be rendered differently.

# %% [markdown]
# ### Other Markdown
#
# #### Superscript and Subscript
#
# H~2~O is a liquid.  2^10^ is 1024.
#
#
# #### Task Lists
#
# - [ ] an unchecked task list item
# - [x] checked item

# %% [markdown]
# ## Not Yet Well Supported
#
# Cells in the sections below show rendering that isn't yet working as it should. Move the cells into the previous section once rendering is cool and the gang.

# %% [markdown]
# ### Graphviz
#
# Graphviz not currently supported.
#
#
# ```{dot}
# graph G {
#   layout=neato
#   run -- intr;
#   intr -- runbl;
#   runbl -- run;
#   run -- kernel;
#   kernel -- zombie;
#   kernel -- sleep;
#   kernel -- runmem;
#   sleep -- swap;
#   swap -- runswap;
#   runswap -- new;
#   runswap -- runmem;
#   new -- runmem;
#   sleep -- runmem;
# }
# ```

# %% [markdown]
# ### Double Bracketed Code
#
#
# ```{{r}}
#
# foo <- "bar"
#
# ```

# %% [markdown]
# ### Shortcodes
#
# {{< var foobar >}} is a shortcode that should have some special treatment.

# %% [markdown]
# ### Math
#
# $$
# e=Mc^2
# $$

# %% [markdown]
# $$
# 1+1
# $$
